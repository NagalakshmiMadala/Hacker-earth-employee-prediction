# %%
import numpy as np
import pandas as pd
import os

import time
from datetime import datetime

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn import model_selection, preprocessing, metrics, ensemble

from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

import lightgbm as lgb

# %%
train_df = pd.read_csv("Train.csv")
test_df = pd.read_csv("Test.csv")
submission_df = pd.read_csv("sample_submission.csv")

train_df.head()
# Out:
#   Employee_ID Gender   Age  Education_Level Relationship_Status     Hometown  \
# 0   EID_23371      F  42.0                4             Married     Franklin
# 1   EID_18000      M  24.0                3              Single  Springfield
# 2    EID_3891      F  58.0                3             Married      Clinton
# 3   EID_17492      F  26.0                3              Single      Lebanon
# 4   EID_22534      F  31.0                1             Married  Springfield
#
#                         Unit Decision_skill_possess  Time_of_service  \
# 0                         IT             Conceptual              4.0
# 1                  Logistics             Analytical              5.0
# 2                    Quality             Conceptual             27.0
# 3  Human Resource Management             Behavioral              4.0
# 4                  Logistics             Conceptual              5.0
#
#    Time_since_promotion  ...  Compensation_and_Benefits  Work_Life_balance  \
# 0                     4  ...                      type2                3.0
# 1                     4  ...                      type2                4.0
# 2                     3  ...                      type2                1.0
# 3                     3  ...                      type2                1.0
# 4                     4  ...                      type3                3.0
#
#    VAR1    VAR2    VAR3  VAR4  VAR5  VAR6  VAR7  Attrition_rate
# 0     4  0.7516  1.8688   2.0     4     5     3          0.1841
# 1     3 -0.9612 -0.4537   2.0     3     5     3          0.0670
# 2     4 -0.9612 -0.4537   3.0     3     8     3          0.0851
# 3     3 -1.8176 -0.4537   NaN     3     7     3          0.0668
# 4     1  0.7516 -0.4537   2.0     2     8     2          0.1827
#
# [5 rows x 24 columns]

# %%
train_ids = set(train_df['Employee_ID'].unique())
test_ids = set(test_df['Employee_ID'].unique())

print("Train ids count : ", len(train_ids))
print("Test ids count : ",len(test_ids))
print("Common ids count : ", len(train_ids.intersection(test_ids)))
# Out:
# Train ids count :  7000
# Test ids count :  3000
# Common ids count :  0

# %%
dupes = train_df.duplicated()
sum(dupes)
# Out:
# 0

# %%
d1=train_df.isnull().sum().to_frame().rename(columns={0: "Train_Null_Values"})
d2=test_df.isnull().sum().to_frame().rename(columns={0: "Test_Null_Values"})
d3=train_df.dtypes.to_frame().rename(columns={0: "Data_Type"})
pd.concat([d1, d2,d3], axis=1)
# Out:
#                            Train_Null_Values  Test_Null_Values Data_Type
# Employee_ID                                0               0.0    object
# Gender                                     0               0.0    object
# Age                                      412             161.0   float64
# Education_Level                            0               0.0     int64
# Relationship_Status                        0               0.0    object
# Hometown                                   0               0.0    object
# Unit                                       0               0.0    object
# Decision_skill_possess                     0               0.0    object
# Time_of_service                          144              52.0   float64
# Time_since_promotion                       0               0.0     int64
# growth_rate                                0               0.0     int64
# Travel_Rate                                0               0.0     int64
# Post_Level                                 0               0.0     int64
# Pay_Scale                                  9               3.0   float64
# Compensation_and_Benefits                  0               0.0    object
# Work_Life_balance                         11               5.0   float64
# VAR1                                       0               0.0     int64
# VAR2                                     577             217.0   float64
# VAR3                                       0               0.0   float64
# VAR4                                     656             298.0   float64
# VAR5                                       0               0.0     int64
# VAR6                                       0               0.0     int64
# VAR7                                       0               0.0     int64
# Attrition_rate                             0               NaN   float64

# %%
missing_cols = [col for col in train_df.columns if train_df[col].isnull().any()]

# %%
missing_cols
# Out:
# ['Age', 'Time_of_service', 'Pay_Scale', 'Work_Life_balance', 'VAR2', 'VAR4']

# %%
train_df.columns
# Out:
# Index(['Employee_ID', 'Gender', 'Age', 'Education_Level',
#        'Relationship_Status', 'Hometown', 'Unit', 'Decision_skill_possess',
#        'Time_of_service', 'Time_since_promotion', 'growth_rate', 'Travel_Rate',
#        'Post_Level', 'Pay_Scale', 'Compensation_and_Benefits',
#        'Work_Life_balance', 'VAR1', 'VAR2', 'VAR3', 'VAR4', 'VAR5', 'VAR6',
#        'VAR7', 'Attrition_rate'],
#       dtype='object')

# %%
cols = train_df.columns

NUM = (train_df._get_numeric_data().columns).to_list()
CAT= cols.difference(NUM).to_list()

# %%
NUM
# Out:
# ['Age',
#  'Education_Level',
#  'Time_of_service',
#  'Time_since_promotion',
#  'growth_rate',
#  'Travel_Rate',
#  'Post_Level',
#  'Pay_Scale',
#  'Work_Life_balance',
#  'VAR1',
#  'VAR2',
#  'VAR3',
#  'VAR4',
#  'VAR5',
#  'VAR6',
#  'VAR7',
#  'Attrition_rate']

# %%
CAT
# Out:
# ['Compensation_and_Benefits',
#  'Decision_skill_possess',
#  'Employee_ID',
#  'Gender',
#  'Hometown',
#  'Relationship_Status',
#  'Unit']

# %%
cat_cols = CAT

nunique_dict = {}
for c in cat_cols:
    nunique_dict[c] = train_df[c].nunique()
    print(c + ': %d values' % nunique_dict[c])
# Out:
# Compensation_and_Benefits: 5 values
# Decision_skill_possess: 4 values
# Employee_ID: 7000 values
# Gender: 2 values
# Hometown: 5 values
# Relationship_Status: 2 values
# Unit: 12 values

# %%
cat_unique=[]
for cat in CAT:
    a=pd.unique(train_df[cat])
    if len(a)>1 and len(a)<500:
        cat_unique.append(cat)
cat_unique
# Out:
# ['Compensation_and_Benefits',
#  'Decision_skill_possess',
#  'Gender',
#  'Hometown',
#  'Relationship_Status',
#  'Unit']

# %%
for cat in cat_unique:
    x=pd.value_counts(train_df[cat])
    x=pd.DataFrame(x)
    x['percentage']=x/len(train_df)
    x['var']=cat
    x['category']=x.index.values
    x.columns=['count','percentage','var','category']
    if cat==cat_unique[0]:
        freq_table=x
    else:
        freq_table=x.append([freq_table])
freq_table
# Out:
#                            count  percentage                        var  \
# IT                          1394    0.199143                       Unit
# Logistics                   1173    0.167571                       Unit
# Sales                        943    0.134714                       Unit
# Operarions                   706    0.100857                       Unit
# R&D                          680    0.097143                       Unit
# Purchasing                   504    0.072000                       Unit
# Accounting and Finance       496    0.070857                       Unit
# Human Resource Management    344    0.049143                       Unit
# Marketing                    212    0.030286                       Unit
# Production                   211    0.030143                       Unit
# Quality                      193    0.027571                       Unit
# Security                     144    0.020571                       Unit
# Married                     4520    0.645714        Relationship_Status
# Single                      2480    0.354286        Relationship_Status
# Lebanon                     2070    0.295714                   Hometown
# Springfield                 1736    0.248000                   Hometown
# Franklin                    1523    0.217571                   Hometown
# Washington                  1106    0.158000                   Hometown
# Clinton                      565    0.080714                   Hometown
# F                           4114    0.587714                     Gender
# M                           2886    0.412286                     Gender
# Conceptual                  1756    0.250857     Decision_skill_possess
# Analytical                  1755    0.250714     Decision_skill_possess
# Directive                   1753    0.250429     Decision_skill_possess
# Behavioral                  1736    0.248000     Decision_skill_possess
# type2                       3945    0.563571  Compensation_and_Benefits
# type3                       2382    0.340286  Compensation_and_Benefits
# type4                        353    0.050429  Compensation_and_Benefits
# type0                        187    0.026714  Compensation_and_Benefits
# type1                        133    0.019000  Compensation_and_Benefits
#
#                                             category
# IT                                                IT
# Logistics                                  Logistics
# Sales                                          Sales
# Operarions                                Operarions
# R&D                                              R&D
# Purchasing                                Purchasing
# Accounting and Finance        Accounting and Finance
# Human Resource Management  Human Resource Management
# Marketing                                  Marketing
# Production                                Production
# Quality                                      Quality
# Security                                    Security
# Married                                      Married
# Single                                        Single
# Lebanon                                      Lebanon
# Springfield                              Springfield
# Franklin                                    Franklin
# Washington                                Washington
# Clinton                                      Clinton
# F                                                  F
# M                                                  M
# Conceptual                                Conceptual
# Analytical                                Analytical
# Directive                                  Directive
# Behavioral                                Behavioral
# type2                                          type2
# type3                                          type3
# type4                                          type4
# type0                                          type0
# type1                                          type1

# %%
num_cols=['Age',
 'Education_Level',
 'Time_of_service',
 'Time_since_promotion',
 'growth_rate',
 'Travel_Rate',
 'Post_Level',
 'Pay_Scale',
 'Work_Life_balance',
 'VAR1',
 'VAR2',
 'VAR3',
 'VAR4',
 'VAR5',
 'VAR6',
 'VAR7']

# %%
missing_values=['VAR4','VAR2','Age','Time_of_service','Work_Life_balance','Pay_Scale']

# %%
cat_unique
# Out:
# ['Compensation_and_Benefits',
#  'Decision_skill_possess',
#  'Gender',
#  'Hometown',
#  'Relationship_Status',
#  'Unit']
